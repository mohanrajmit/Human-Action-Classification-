# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Human-Action-Classification-/blob/master/3dcnn_gray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://storage.googleapis.com/thumos14_files/UCF101_videos.zip
# Out:
# --2022-10-01 06:09:26--  https://storage.googleapis.com/thumos14_files/UCF101_videos.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.115.128, 172.253.122.128, 172.253.63.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.115.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6960400115 (6.5G) [binary/octet-stream]
# Saving to: ‘UCF101_videos.zip’
#
# UCF101_videos.zip   100%[===================>]   6.48G  75.6MB/s    in 2m 10s
#
# 2022-10-01 06:11:36 (51.2 MB/s) - ‘UCF101_videos.zip’ saved [6960400115/6960400115]

# %%
# !unzip /content/UCF101_videos.zip

# %%
import os
files = os.listdir("/content/UCF101")
X = []
labels = []
labellist = []

# %%
files
# Out:
# ['v_BasketballDunk_g21_c03.avi',
#  'v_BoxingSpeedBag_g08_c04.avi',
#  'v_Biking_g04_c04.avi',
#  'v_FrisbeeCatch_g20_c03.avi',
#  'v_JumpRope_g21_c03.avi',
#  'v_HighJump_g19_c03.avi',
#  'v_Haircut_g11_c05.avi',
#  'v_CliffDiving_g14_c05.avi',
#  'v_HorseRace_g13_c03.avi',
#  'v_CuttingInKitchen_g18_c01.avi',
#  'v_BaseballPitch_g03_c04.avi',
#  'v_CleanAndJerk_g24_c02.avi',
#  'v_Knitting_g10_c06.avi',
#  'v_PlayingFlute_g21_c04.avi',
#  'v_Diving_g10_c01.avi',
#  'v_PlayingDhol_g22_c01.avi',
#  'v_Archery_g10_c02.avi',
#  'v_Bowling_g09_c04.avi',
#  'v_BoxingPunchingBag_g23_c01.avi',
#  'v_HandstandWalking_g15_c04.avi',
#  'v_FieldHockeyPenalty_g17_c04.avi',
#  'v_FrontCrawl_g08_c03.avi',
#  'v_HandstandWalking_g22_c01.avi',
#  'v_Lunges_g02_c03.avi',
#  'v_MilitaryParade_g23_c03.avi',
#  'v_HighJump_g14_c04.avi',
#  'v_CricketBowling_g05_c01.avi',
#  'v_BoxingPunchingBag_g10_c03.avi',
#  'v_BoxingPunchingBag_g13_c02.avi',
#  'v_Billiards_g18_c05.avi',
#  'v_Drumming_g04_c06.avi',
#  'v_JumpRope_g15_c02.avi',
#  'v_PizzaTossing_g19_c03.avi',
#  'v_HighJump_g02_c04.avi',
#  'v_BandMarching_g23_c06.avi',
#  'v_HeadMassage_g14_c06.avi',
#  'v_Knitting_g06_c01.avi',
#  'v_HulaHoop_g16_c06.avi',
#  'v_PlayingDaf_g05_c04.avi',
#  'v_Bowling_g02_c02.avi',
#  'v_FrontCrawl_g04_c06.avi',
#  'v_HammerThrow_g04_c03.avi',
#  'v_Drumming_g21_c01.avi',
#  'v_CliffDiving_g01_c04.avi',
#  'v_Lunges_g05_c01.avi',
#  'v_IceDancing_g09_c02.avi',
#  'v_MoppingFloor_g13_c03.avi',
#  'v_ApplyLipstick_g16_c04.avi',
#  'v_BreastStroke_g02_c01.avi',
#  'v_MoppingFloor_g18_c02.avi',
#  'v_BabyCrawling_g19_c01.avi',
#  'v_BenchPress_g15_c05.avi',
#  'v_CleanAndJerk_g06_c04.avi',
#  'v_BlowDryHair_g04_c01.avi',
#  'v_JumpRope_g20_c06.avi',
#  'v_JumpRope_g08_c01.avi',
#  'v_BaseballPitch_g25_c03.avi',
#  'v_Diving_g12_c02.avi',
#  'v_Archery_g05_c01.avi',
#  'v_PlayingDaf_g16_c03.avi',
#  'v_ApplyLipstick_g21_c02.avi',
#  'v_FloorGymnastics_g18_c05.avi',
#  'v_ApplyEyeMakeup_g20_c02.avi',
#  'v_PlayingFlute_g24_c03.avi',
#  'v_PizzaTossing_g10_c02.avi',
#  'v_JumpingJack_g22_c02.avi',
#  'v_LongJump_g07_c01.avi',
#  'v_CliffDiving_g10_c02.avi',
#  'v_ApplyLipstick_g13_c02.avi',
#  'v_BrushingTeeth_g04_c02.avi',
#  'v_BabyCrawling_g06_c06.avi',
#  'v_PizzaTossing_g25_c03.avi',
#  'v_FloorGymnastics_g09_c07.avi',
#  'v_BalanceBeam_g09_c01.avi',
#  'v_ParallelBars_g04_c03.avi',
#  'v_BoxingPunchingBag_g10_c02.avi',
#  'v_Mixing_g15_c07.avi',
#  'v_Fencing_g02_c05.avi',
#  'v_ParallelBars_g10_c04.avi',
#  'v_IceDancing_g21_c03.avi',
#  'v_CuttingInKitchen_g02_c01.avi',
#  'v_MilitaryParade_g17_c05.avi',
#  'v_CricketBowling_g21_c04.avi',
#  'v_Nunchucks_g11_c05.avi',
#  'v_BaseballPitch_g02_c04.avi',
#  'v_JugglingBalls_g21_c01.avi',
#  'v_Drumming_g16_c01.avi',
#  'v_PlayingFlute_g19_c04.avi',
#  'v_HorseRace_g22_c04.avi',
#  'v_CricketBowling_g25_c04.avi',
#  'v_Lunges_g17_c04.avi',
#  'v_Drumming_g21_c05.avi',
#  'v_BabyCrawling_g17_c02.avi',
#  'v_ParallelBars_g04_c05.avi',
#  'v_HighJump_g13_c03.avi',
#  'v_HammerThrow_g07_c02.avi',
#  'v_PizzaTossing_g18_c04.avi',
#  'v_BodyWeightSquats_g12_c03.avi',
#  'v_BandMarching_g02_c04.avi',
#  'v_Haircut_g15_c03.avi',
#  'v_HammerThrow_g01_c05.avi',
#  'v_HorseRace_g03_c05.avi',
#  'v_GolfSwing_g06_c04.avi',
#  'v_JugglingBalls_g14_c03.avi',
#  'v_CuttingInKitchen_g22_c03.avi',
#  'v_Hammering_g22_c01.avi',
#  'v_Biking_g14_c04.avi',
#  'v_HeadMassage_g08_c07.avi',
#  'v_BreastStroke_g01_c01.avi',
#  'v_BabyCrawling_g13_c03.avi',
#  'v_BoxingSpeedBag_g15_c02.avi',
#  'v_BoxingPunchingBag_g12_c05.avi',
#  'v_BreastStroke_g03_c01.avi',
#  'v_BaseballPitch_g06_c01.avi',
#  'v_BabyCrawling_g10_c03.avi',
#  'v_HorseRiding_g20_c07.avi',
#  'v_Kayaking_g16_c02.avi',
#  'v_BlowDryHair_g08_c03.avi',
#  'v_HeadMassage_g25_c03.avi',
#  'v_HandstandWalking_g15_c03.avi',
#  'v_BrushingTeeth_g07_c06.avi',
#  'v_BrushingTeeth_g23_c06.avi',
#  'v_Hammering_g12_c05.avi',
#  'v_HeadMassage_g10_c01.avi',
#  'v_MilitaryParade_g19_c07.avi',
#  'v_Billiards_g09_c01.avi',
#  'v_MoppingFloor_g16_c02.avi',
#  'v_BalanceBeam_g07_c01.avi',
#  'v_Nunchucks_g24_c04.avi',
#  'v_BodyWeightSquats_g12_c02.avi',
#  'v_JumpRope_g16_c05.avi',
#  'v_FieldHockeyPenalty_g03_c01.avi',
#  'v_ParallelBars_g02_c02.avi',
#  'v_BenchPress_g06_c07.avi',
#  'v_PizzaTossing_g01_c04.avi',
#  'v_HandstandPushups_g20_c03.avi',
#  'v_BaseballPitch_g02_c03.avi',
#  'v_Archery_g09_c06.avi',
#  'v_Drumming_g10_c01.avi',
#  'v_BoxingPunchingBag_g04_c04.avi',
#  'v_Diving_g04_c02.avi',
#  'v_ApplyLipstick_g16_c03.avi',
#  'v_BoxingPunchingBag_g14_c03.avi',
#  'v_Drumming_g20_c02.avi',
#  'v_ApplyEyeMakeup_g05_c05.avi',
#  'v_PlayingDaf_g24_c03.avi',
#  'v_HammerThrow_g24_c03.avi',
#  'v_Fencing_g14_c03.avi',
#  'v_JumpRope_g14_c02.avi',
#  'v_JugglingBalls_g20_c02.avi',
#  'v_HandstandPushups_g21_c03.avi',
#  'v_HorseRace_g06_c06.avi',
#  'v_LongJump_g17_c02.avi',
#  'v_CuttingInKitchen_g16_c03.avi',
#  'v_PlayingSitar_g02_c03.avi',
#  'v_ApplyEyeMakeup_g05_c04.avi',
#  'v_PlayingPiano_g13_c02.avi',
#  'v_Lunges_g04_c01.avi',
#  'v_GolfSwing_g01_c05.avi',
#  'v_Kayaking_g24_c01.avi',
#  'v_PlayingDhol_g03_c07.avi',
#  'v_FrontCrawl_g19_c02.avi',
#  'v_FloorGymnastics_g06_c03.avi',
#  'v_HorseRace_g06_c01.avi',
#  'v_Drumming_g21_c03.avi',
#  'v_BoxingPunchingBag_g14_c01.avi',
#  'v_ApplyLipstick_g25_c01.avi',
#  'v_Mixing_g03_c02.avi',
#  'v_Bowling_g14_c01.avi',
#  'v_BoxingSpeedBag_g05_c05.avi',
#  'v_Kayaking_g11_c02.avi',
#  'v_PlayingCello_g14_c04.avi',
#  'v_BasketballDunk_g24_c01.avi',
#  'v_GolfSwing_g16_c01.avi',
#  'v_CleanAndJerk_g06_c01.avi',
#  'v_PlayingSitar_g18_c03.avi',
#  'v_HorseRace_g25_c03.avi',
#  'v_Mixing_g22_c02.avi',
#  'v_Drumming_g18_c05.avi',
#  'v_Billiards_g02_c05.avi',
#  'v_Hammering_g22_c07.avi',
#  'v_HammerThrow_g20_c04.avi',
#  'v_CricketShot_g10_c01.avi',
#  'v_FieldHockeyPenalty_g06_c01.avi',
#  'v_MoppingFloor_g14_c01.avi',
#  'v_IceDancing_g18_c01.avi',
#  'v_CricketBowling_g09_c04.avi',
#  'v_ApplyEyeMakeup_g04_c05.avi',
#  'v_Hammering_g02_c03.avi',
#  'v_HandstandPushups_g17_c05.avi',
#  'v_Bowling_g01_c05.avi',
#  'v_HighJump_g01_c03.avi',
#  'v_ApplyLipstick_g19_c03.avi',
#  'v_BasketballDunk_g23_c03.avi',
#  'v_Biking_g19_c02.avi',
#  'v_BoxingSpeedBag_g24_c03.avi',
#  'v_CliffDiving_g12_c03.avi',
#  'v_FrisbeeCatch_g11_c01.avi',
#  'v_Bowling_g24_c07.avi',
#  'v_HorseRiding_g22_c03.avi',
#  'v_JumpRope_g03_c03.avi',
#  'v_Biking_g19_c03.avi',
#  'v_FloorGymnastics_g15_c01.avi',
#  'v_BaseballPitch_g09_c01.avi',
#  'v_BrushingTeeth_g24_c04.avi',
#  'v_Kayaking_g19_c03.avi',
#  'v_BrushingTeeth_g23_c02.avi',
#  'v_BenchPress_g15_c01.avi',
#  'v_CricketShot_g07_c04.avi',
#  'v_Billiards_g04_c02.avi',
#  'v_BlowingCandles_g13_c02.avi',
#  'v_Diving_g08_c01.avi',
#  'v_HandstandPushups_g17_c04.avi',
#  'v_MoppingFloor_g21_c04.avi',
#  'v_ApplyLipstick_g16_c02.avi',
#  'v_Billiards_g21_c06.avi',
#  'v_IceDancing_g03_c06.avi',
#  'v_ApplyEyeMakeup_g25_c05.avi',
#  'v_BodyWeightSquats_g23_c01.avi',
#  'v_BrushingTeeth_g02_c05.avi',
#  'v_Basketball_g15_c01.avi',
#  'v_HorseRace_g11_c03.avi',
#  'v_PlayingCello_g23_c01.avi',
#  'v_PizzaTossing_g22_c04.avi',
#  'v_PlayingDhol_g14_c07.avi',
#  'v_LongJump_g16_c04.avi',
#  'v_HorseRiding_g12_c07.avi',
#  'v_CricketBowling_g01_c01.avi',
#  'v_JumpRope_g12_c01.avi',
#  'v_PlayingCello_g13_c07.avi',
#  'v_MoppingFloor_g09_c03.avi',
#  'v_BlowDryHair_g09_c03.avi',
#  'v_Lunges_g07_c02.avi',
#  'v_Fencing_g10_c04.avi',
#  'v_IceDancing_g23_c05.avi',
#  'v_PizzaTossing_g13_c03.avi',
#  'v_BasketballDunk_g14_c07.avi',
#  'v_PlayingDhol_g06_c06.avi',
#  'v_BaseballPitch_g21_c01.avi',
#  'v_PlayingDaf_g13_c01.avi',
#  'v_FieldHockeyPenalty_g14_c02.avi',
#  'v_HulaHoop_g05_c02.avi',
#  'v_GolfSwing_g16_c02.avi',
#  'v_BlowDryHair_g12_c02.avi',
#  'v_HammerThrow_g05_c02.avi',
#  'v_PlayingFlute_g09_c07.avi',
#  'v_BlowingCandles_g07_c01.avi',
#  'v_Billiards_g11_c07.avi',
#  'v_GolfSwing_g07_c04.avi',
#  'v_FrontCrawl_g16_c03.avi',
#  'v_MoppingFloor_g04_c03.avi',
#  'v_LongJump_g03_c01.avi',
#  'v_BalanceBeam_g24_c01.avi',
#  'v_PlayingGuitar_g18_c03.avi',
#  'v_HandstandWalking_g01_c04.avi',
#  'v_HorseRiding_g04_c06.avi',
#  'v_HorseRiding_g22_c06.avi',
#  'v_IceDancing_g09_c01.avi',
#  'v_CricketBowling_g25_c03.avi',
#  'v_HandstandWalking_g02_c03.avi',
#  'v_JugglingBalls_g11_c05.avi',
#  'v_FrisbeeCatch_g19_c01.avi',
#  'v_BoxingSpeedBag_g20_c01.avi',
#  'v_HandstandWalking_g17_c02.avi',
#  'v_BasketballDunk_g03_c03.avi',
#  'v_CricketShot_g03_c07.avi',
#  'v_PlayingCello_g05_c06.avi',
#  'v_Drumming_g04_c03.avi',
#  'v_BabyCrawling_g21_c03.avi',
#  'v_Drumming_g25_c05.avi',
#  'v_Knitting_g05_c02.avi',
#  'v_FrontCrawl_g04_c03.avi',
#  'v_PlayingCello_g18_c01.avi',
#  'v_HandstandPushups_g09_c02.avi',
#  'v_FloorGymnastics_g11_c02.avi',
#  'v_CricketShot_g18_c02.avi',
#  'v_Nunchucks_g08_c07.avi',
#  'v_PlayingGuitar_g09_c04.avi',
#  'v_FloorGymnastics_g14_c05.avi',
#  'v_CricketShot_g11_c07.avi',
#  'v_HandstandPushups_g10_c01.avi',
#  'v_Nunchucks_g14_c03.avi',
#  'v_LongJump_g20_c01.avi',
#  'v_ApplyEyeMakeup_g05_c01.avi',
#  'v_BenchPress_g23_c05.avi',
#  'v_HeadMassage_g19_c01.avi',
#  'v_BasketballDunk_g14_c01.avi',
#  'v_HorseRiding_g16_c05.avi',
#  'v_BodyWeightSquats_g02_c03.avi',
#  'v_GolfSwing_g05_c04.avi',
#  'v_BlowingCandles_g11_c01.avi',
#  'v_CliffDiving_g23_c02.avi',
#  'v_HandstandPushups_g20_c07.avi',
#  'v_PlayingCello_g06_c02.avi',
#  'v_CuttingInKitchen_g05_c05.avi',
#  'v_JumpRope_g16_c03.avi',
#  'v_Archery_g23_c07.avi',
#  'v_Haircut_g03_c02.avi',
#  'v_PlayingCello_g24_c07.avi',
#  'v_BaseballPitch_g15_c01.avi',
#  'v_CricketShot_g20_c05.avi',
#  'v_Nunchucks_g09_c04.avi',
#  'v_ApplyLipstick_g17_c02.avi',
#  'v_HeadMassage_g12_c07.avi',
#  'v_LongJump_g12_c02.avi',
#  'v_CliffDiving_g02_c02.avi',
#  'v_BoxingSpeedBag_g01_c02.avi',
#  'v_HeadMassage_g02_c07.avi',
#  'v_JumpRope_g09_c06.avi',
#  'v_PlayingDhol_g23_c01.avi',
#  'v_BlowDryHair_g12_c01.avi',
#  'v_PlayingCello_g01_c01.avi',
#  'v_BenchPress_g20_c03.avi',
#  'v_Drumming_g20_c03.avi',
#  'v_JumpRope_g12_c03.avi',
#  'v_BreastStroke_g18_c03.avi',
#  'v_Biking_g15_c01.avi',
#  'v_HandstandWalking_g25_c02.avi',
#  'v_HammerThrow_g15_c04.avi',
#  'v_FloorGymnastics_g19_c02.avi',
#  'v_BrushingTeeth_g06_c01.avi',
#  'v_Billiards_g20_c03.avi',
#  'v_CliffDiving_g01_c03.avi',
#  'v_BlowingCandles_g25_c04.avi',
#  'v_CricketShot_g08_c02.avi',
#  'v_LongJump_g19_c01.avi',
#  'v_JugglingBalls_g12_c05.avi',
#  'v_Drumming_g19_c01.avi',
#  'v_Haircut_g05_c02.avi',
#  'v_PlayingPiano_g20_c02.avi',
#  'v_Biking_g03_c01.avi',
#  'v_FrisbeeCatch_g05_c04.avi',
#  'v_Billiards_g12_c01.avi',
#  'v_Bowling_g07_c02.avi',
#  'v_Nunchucks_g03_c04.avi',
#  'v_BrushingTeeth_g02_c03.avi',
#  'v_GolfSwing_g23_c06.avi',
#  'v_PlayingFlute_g18_c03.avi',
#  'v_HighJump_g19_c04.avi',
#  'v_FrontCrawl_g22_c06.avi',
#  'v_CricketBowling_g21_c05.avi',
#  'v_Diving_g03_c05.avi',
#  'v_Fencing_g07_c01.avi',
#  'v_FrisbeeCatch_g11_c02.avi',
#  'v_ApplyEyeMakeup_g02_c02.avi',
#  'v_BoxingPunchingBag_g02_c07.avi',
#  'v_HammerThrow_g12_c03.avi',
#  'v_BlowingCandles_g04_c03.avi',
#  'v_CricketBowling_g19_c03.avi',
#  'v_PizzaTossing_g19_c05.avi',
#  'v_FieldHockeyPenalty_g12_c03.avi',
#  'v_Billiards_g02_c01.avi',
#  'v_PlayingCello_g12_c04.avi',
#  'v_Kayaking_g16_c07.avi',
#  'v_Diving_g14_c01.avi',
#  'v_Knitting_g08_c03.avi',
#  'v_PlayingGuitar_g02_c03.avi',
#  'v_HandstandPushups_g25_c06.avi',
#  'v_Billiards_g01_c03.avi',
#  'v_CricketShot_g12_c04.avi',
#  'v_PlayingPiano_g19_c01.avi',
#  'v_Archery_g08_c03.avi',
#  'v_BalanceBeam_g13_c01.avi',
#  'v_ApplyEyeMakeup_g15_c02.avi',
#  'v_BaseballPitch_g07_c07.avi',
#  'v_CliffDiving_g07_c04.avi',
#  'v_FieldHockeyPenalty_g10_c02.avi',
#  'v_FloorGymnastics_g14_c01.avi',
#  'v_Nunchucks_g03_c02.avi',
#  'v_Lunges_g11_c05.avi',
#  'v_CricketBowling_g18_c05.avi',
#  'v_BalanceBeam_g05_c04.avi',
#  'v_IceDancing_g02_c02.avi',
#  'v_BlowDryHair_g09_c01.avi',
#  'v_Billiards_g03_c02.avi',
#  'v_BaseballPitch_g21_c02.avi',
#  'v_CricketBowling_g20_c03.avi',
#  'v_FrontCrawl_g14_c02.avi',
#  'v_ApplyLipstick_g08_c02.avi',
#  'v_Knitting_g19_c03.avi',
#  'v_ApplyLipstick_g07_c04.avi',
#  'v_HeadMassage_g05_c05.avi',
#  'v_HighJump_g11_c05.avi',
#  'v_FloorGymnastics_g07_c04.avi',
#  'v_Fencing_g16_c03.avi',
#  'v_HighJump_g09_c03.avi',
#  'v_CliffDiving_g19_c06.avi',
#  'v_Hammering_g09_c04.avi',
#  'v_CleanAndJerk_g09_c03.avi',
#  'v_PlayingGuitar_g04_c01.avi',
#  'v_PlayingSitar_g08_c05.avi',
#  'v_Lunges_g14_c05.avi',
#  'v_PizzaTossing_g04_c04.avi',
#  'v_Nunchucks_g02_c05.avi',
#  'v_PlayingGuitar_g19_c04.avi',
#  'v_Kayaking_g24_c06.avi',
#  'v_PlayingGuitar_g07_c05.avi',
#  'v_BenchPress_g25_c03.avi',
#  'v_BoxingPunchingBag_g09_c03.avi',
#  'v_MilitaryParade_g12_c05.avi',
#  'v_CricketShot_g03_c01.avi',
#  'v_HammerThrow_g23_c02.avi',
#  'v_HulaHoop_g13_c01.avi',
#  'v_ApplyEyeMakeup_g19_c01.avi',
#  'v_Kayaking_g06_c05.avi',
#  'v_BenchPress_g01_c03.avi',
#  'v_HandstandWalking_g01_c01.avi',
#  'v_BlowingCandles_g09_c01.avi',
#  'v_CricketShot_g05_c01.avi',
#  'v_PlayingDaf_g08_c03.avi',
#  'v_PlayingCello_g06_c05.avi',
#  'v_CuttingInKitchen_g04_c03.avi',
#  'v_BenchPress_g14_c01.avi',
#  'v_CleanAndJerk_g22_c03.avi',
#  'v_MilitaryParade_g05_c03.avi',
#  'v_ParallelBars_g19_c02.avi',
#  'v_PlayingDhol_g12_c05.avi',
#  'v_BandMarching_g13_c02.avi',
#  'v_JumpingJack_g10_c05.avi',
#  'v_BasketballDunk_g14_c03.avi',
#  'v_BandMarching_g10_c06.avi',
#  'v_Billiards_g06_c02.avi',
#  'v_Fencing_g09_c03.avi',
#  'v_JugglingBalls_g10_c03.avi',
#  'v_Biking_g03_c03.avi',
#  'v_HulaHoop_g20_c07.avi',
#  'v_PlayingGuitar_g10_c05.avi',
#  'v_HammerThrow_g15_c03.avi',
#  'v_PlayingFlute_g19_c06.avi',
#  'v_Haircut_g05_c03.avi',
#  'v_PlayingDhol_g13_c06.avi',
#  'v_HandstandPushups_g09_c04.avi',
#  'v_BandMarching_g13_c01.avi',
#  'v_ApplyEyeMakeup_g17_c04.avi',
#  'v_BenchPress_g09_c01.avi',
#  'v_BrushingTeeth_g05_c03.avi',
#  'v_ApplyLipstick_g25_c03.avi',
#  'v_ApplyLipstick_g02_c01.avi',
#  'v_BlowDryHair_g21_c05.avi',
#  'v_PlayingDaf_g19_c01.avi',
#  'v_JumpingJack_g03_c03.avi',
#  'v_Hammering_g18_c07.avi',
#  'v_HulaHoop_g03_c02.avi',
#  'v_JugglingBalls_g15_c02.avi',
#  'v_Drumming_g13_c05.avi',
#  'v_HammerThrow_g08_c04.avi',
#  'v_HorseRiding_g22_c01.avi',
#  'v_CricketBowling_g24_c03.avi',
#  'v_PlayingGuitar_g07_c03.avi',
#  'v_FieldHockeyPenalty_g05_c03.avi',
#  'v_ApplyEyeMakeup_g15_c04.avi',
#  'v_Drumming_g24_c03.avi',
#  'v_HulaHoop_g18_c04.avi',
#  'v_BabyCrawling_g07_c01.avi',
#  'v_Haircut_g12_c04.avi',
#  'v_CliffDiving_g07_c06.avi',
#  'v_BalanceBeam_g21_c01.avi',
#  'v_Nunchucks_g15_c01.avi',
#  'v_JumpingJack_g06_c05.avi',
#  'v_Lunges_g05_c04.avi',
#  'v_BlowDryHair_g05_c05.avi',
#  'v_PlayingDhol_g12_c04.avi',
#  'v_Billiards_g06_c01.avi',
#  'v_BodyWeightSquats_g09_c01.avi',
#  'v_IceDancing_g19_c07.avi',
#  'v_Mixing_g20_c04.avi',
#  'v_MilitaryParade_g15_c05.avi',
#  'v_Fencing_g16_c04.avi',
#  'v_JumpRope_g07_c03.avi',
#  'v_BalanceBeam_g20_c03.avi',
#  'v_Mixing_g12_c05.avi',
#  'v_FrontCrawl_g22_c04.avi',
#  'v_HandstandWalking_g18_c02.avi',
#  'v_HorseRace_g24_c06.avi',
#  'v_BlowDryHair_g25_c03.avi',
#  'v_Basketball_g21_c04.avi',
#  'v_JugglingBalls_g01_c02.avi',
#  'v_HighJump_g04_c05.avi',
#  'v_FloorGymnastics_g10_c04.avi',
#  'v_JumpRope_g19_c01.avi',
#  'v_Billiards_g14_c06.avi',
#  'v_HighJump_g05_c03.avi',
#  'v_MilitaryParade_g12_c03.avi',
#  'v_CricketShot_g09_c05.avi',
#  'v_CliffDiving_g20_c06.avi',
#  'v_BlowDryHair_g21_c03.avi',
#  'v_PlayingCello_g02_c07.avi',
#  'v_Basketball_g05_c03.avi',
#  'v_CleanAndJerk_g15_c01.avi',
#  'v_PlayingDaf_g13_c04.avi',
#  'v_LongJump_g07_c03.avi',
#  'v_BandMarching_g22_c03.avi',
#  'v_Bowling_g15_c01.avi',
#  'v_MilitaryParade_g01_c04.avi',
#  'v_CleanAndJerk_g08_c04.avi',
#  'v_JavelinThrow_g04_c01.avi',
#  'v_CleanAndJerk_g23_c02.avi',
#  'v_PlayingFlute_g02_c01.avi',
#  'v_Lunges_g05_c03.avi',
#  'v_BasketballDunk_g17_c01.avi',
#  'v_Mixing_g18_c02.avi',
#  'v_HorseRace_g11_c07.avi',
#  'v_IceDancing_g24_c05.avi',
#  'v_CliffDiving_g23_c04.avi',
#  'v_PlayingGuitar_g13_c04.avi',
#  'v_ApplyEyeMakeup_g13_c03.avi',
#  'v_Diving_g15_c05.avi',
#  'v_PlayingPiano_g15_c01.avi',
#  'v_Mixing_g18_c01.avi',
#  'v_Drumming_g24_c04.avi',
#  'v_PizzaTossing_g04_c01.avi',
#  'v_PlayingDhol_g10_c02.avi',
#  'v_IceDancing_g08_c01.avi',
#  'v_Biking_g16_c04.avi',
#  'v_CliffDiving_g14_c01.avi',
#  'v_Bowling_g17_c05.avi',
#  'v_BoxingPunchingBag_g22_c05.avi',
#  'v_BasketballDunk_g16_c04.avi',
#  'v_CleanAndJerk_g07_c03.avi',
#  'v_HorseRace_g16_c02.avi',
#  'v_HeadMassage_g14_c01.avi',
#  'v_Biking_g13_c06.avi',
#  'v_HorseRiding_g19_c03.avi',
#  'v_BodyWeightSquats_g11_c01.avi',
#  'v_JumpingJack_g19_c07.avi',
#  'v_HandstandPushups_g15_c05.avi',
#  'v_Mixing_g23_c04.avi',
#  'v_CricketShot_g18_c05.avi',
#  'v_Billiards_g01_c04.avi',
#  'v_CleanAndJerk_g23_c03.avi',
#  'v_Nunchucks_g04_c05.avi',
#  'v_PlayingGuitar_g05_c05.avi',
#  'v_Diving_g05_c03.avi',
#  'v_HammerThrow_g20_c05.avi',
#  'v_HandstandWalking_g23_c03.avi',
#  'v_CricketBowling_g13_c02.avi',
#  'v_BoxingSpeedBag_g09_c04.avi',
#  'v_Basketball_g20_c05.avi',
#  'v_BaseballPitch_g23_c03.avi',
#  'v_JugglingBalls_g17_c01.avi',
#  'v_PlayingSitar_g16_c04.avi',
#  'v_JavelinThrow_g10_c04.avi',
#  'v_BoxingPunchingBag_g11_c04.avi',
#  'v_HorseRace_g06_c02.avi',
#  'v_PlayingCello_g09_c03.avi',
#  'v_Biking_g20_c06.avi',
#  'v_HorseRace_g18_c02.avi',
#  'v_ParallelBars_g22_c01.avi',
#  'v_CricketBowling_g02_c07.avi',
#  'v_FieldHockeyPenalty_g10_c03.avi',
#  'v_PlayingSitar_g03_c03.avi',
#  'v_HorseRiding_g16_c01.avi',
#  'v_Mixing_g14_c04.avi',
#  'v_Basketball_g15_c02.avi',
#  'v_Basketball_g08_c03.avi',
#  'v_BoxingSpeedBag_g10_c03.avi',
#  'v_CricketBowling_g18_c03.avi',
#  'v_HulaHoop_g13_c03.avi',
#  'v_BoxingPunchingBag_g05_c01.avi',
#  'v_FloorGymnastics_g10_c01.avi',
#  'v_PlayingDhol_g16_c05.avi',
#  'v_BaseballPitch_g01_c05.avi',
#  'v_BlowDryHair_g20_c05.avi',
#  'v_BandMarching_g01_c07.avi',
#  'v_MilitaryParade_g13_c04.avi',
#  'v_BenchPress_g21_c03.avi',
#  'v_BenchPress_g20_c04.avi',
#  'v_FloorGymnastics_g08_c04.avi',
#  'v_HandstandPushups_g22_c04.avi',
#  'v_GolfSwing_g22_c02.avi',
#  'v_Knitting_g13_c01.avi',
#  'v_PlayingSitar_g02_c04.avi',
#  'v_BaseballPitch_g05_c01.avi',
#  'v_HeadMassage_g21_c04.avi',
#  'v_JumpingJack_g21_c01.avi',
#  'v_Hammering_g24_c03.avi',
#  'v_CuttingInKitchen_g04_c01.avi',
#  'v_Biking_g22_c01.avi',
#  'v_FrontCrawl_g17_c07.avi',
#  'v_HeadMassage_g07_c05.avi',
#  'v_FrontCrawl_g23_c06.avi',
#  'v_FieldHockeyPenalty_g10_c01.avi',
#  'v_ApplyEyeMakeup_g23_c05.avi',
#  'v_BlowDryHair_g22_c01.avi',
#  'v_BaseballPitch_g14_c04.avi',
#  'v_CricketBowling_g21_c06.avi',
#  'v_Archery_g24_c05.avi',
#  'v_PlayingDaf_g19_c02.avi',
#  'v_Mixing_g24_c04.avi',
#  'v_BreastStroke_g06_c01.avi',
#  'v_PlayingPiano_g14_c01.avi',
#  'v_BodyWeightSquats_g10_c05.avi',
#  'v_ApplyEyeMakeup_g20_c03.avi',
#  'v_HorseRiding_g16_c06.avi',
#  'v_CleanAndJerk_g25_c02.avi',
#  'v_JumpingJack_g18_c03.avi',
#  'v_BoxingPunchingBag_g05_c07.avi',
#  'v_Nunchucks_g23_c05.avi',
#  'v_HorseRiding_g20_c03.avi',
#  'v_JumpingJack_g14_c03.avi',
#  'v_BrushingTeeth_g05_c01.avi',
#  'v_IceDancing_g05_c03.avi',
#  'v_JugglingBalls_g08_c01.avi',
#  'v_MilitaryParade_g07_c04.avi',
#  'v_BenchPress_g13_c03.avi',
#  'v_Drumming_g17_c02.avi',
#  'v_Drumming_g16_c03.avi',
#  'v_PlayingFlute_g03_c03.avi',
#  'v_JavelinThrow_g25_c05.avi',
#  'v_JumpingJack_g07_c04.avi',
#  'v_FieldHockeyPenalty_g08_c04.avi',
#  'v_HandstandWalking_g05_c04.avi',
#  'v_PlayingPiano_g19_c03.avi',
#  'v_CliffDiving_g11_c02.avi',
#  'v_BoxingPunchingBag_g17_c04.avi',
#  'v_LongJump_g24_c02.avi',
#  'v_PlayingDhol_g04_c07.avi',
#  'v_MilitaryParade_g15_c06.avi',
#  'v_PlayingFlute_g11_c04.avi',
#  'v_JumpRope_g02_c05.avi',
#  'v_Drumming_g16_c04.avi',
#  'v_JumpingJack_g10_c02.avi',
#  'v_JumpRope_g23_c04.avi',
#  'v_FieldHockeyPenalty_g24_c02.avi',
#  'v_PlayingDhol_g14_c03.avi',
#  'v_BaseballPitch_g10_c04.avi',
#  'v_Diving_g13_c06.avi',
#  'v_PlayingDhol_g01_c02.avi',
#  'v_GolfSwing_g23_c02.avi',
#  'v_BenchPress_g08_c05.avi',
#  'v_PlayingDaf_g02_c03.avi',
#  'v_JugglingBalls_g07_c05.avi',
#  'v_Mixing_g21_c04.avi',
#  'v_Basketball_g14_c05.avi',
#  'v_BoxingPunchingBag_g04_c07.avi',
#  'v_Kayaking_g07_c03.avi',
#  'v_PlayingPiano_g14_c02.avi',
#  'v_BoxingPunchingBag_g09_c06.avi',
#  'v_JumpingJack_g10_c01.avi',
#  'v_JumpRope_g05_c01.avi',
#  'v_PlayingGuitar_g15_c05.avi',
#  'v_PlayingCello_g16_c03.avi',
#  'v_PlayingDaf_g01_c02.avi',
#  'v_FloorGymnastics_g20_c05.avi',
#  'v_BaseballPitch_g20_c02.avi',
#  'v_PlayingSitar_g21_c06.avi',
#  'v_JavelinThrow_g16_c01.avi',
#  'v_Drumming_g16_c02.avi',
#  'v_ApplyEyeMakeup_g04_c06.avi',
#  'v_Basketball_g19_c05.avi',
#  'v_BenchPress_g10_c02.avi',
#  'v_HeadMassage_g20_c02.avi',
#  'v_Mixing_g19_c03.avi',
#  'v_FrontCrawl_g16_c02.avi',
#  'v_Hammering_g14_c07.avi',
#  'v_CricketBowling_g17_c02.avi',
#  'v_HorseRiding_g08_c03.avi',
#  'v_PlayingPiano_g16_c06.avi',
#  'v_MilitaryParade_g15_c07.avi',
#  'v_PizzaTossing_g13_c02.avi',
#  'v_BaseballPitch_g19_c01.avi',
#  'v_FloorGymnastics_g03_c02.avi',
#  'v_GolfSwing_g18_c01.avi',
#  'v_BenchPress_g24_c06.avi',
#  'v_FrisbeeCatch_g19_c06.avi',
#  'v_Mixing_g17_c02.avi',
#  'v_CricketBowling_g15_c02.avi',
#  'v_PlayingCello_g25_c03.avi',
#  'v_ParallelBars_g24_c03.avi',
#  'v_CricketShot_g22_c05.avi',
#  'v_PlayingCello_g22_c04.avi',
#  'v_IceDancing_g14_c01.avi',
#  'v_Hammering_g02_c02.avi',
#  'v_BlowDryHair_g05_c01.avi',
#  'v_BoxingPunchingBag_g18_c04.avi',
#  'v_FrisbeeCatch_g12_c04.avi',
#  'v_PlayingDhol_g06_c07.avi',
#  'v_BenchPress_g06_c04.avi',
#  'v_CliffDiving_g24_c05.avi',
#  'v_JavelinThrow_g08_c02.avi',
#  'v_PlayingDhol_g06_c02.avi',
#  'v_Knitting_g17_c03.avi',
#  'v_HorseRace_g15_c01.avi',
#  'v_HammerThrow_g24_c02.avi',
#  'v_LongJump_g08_c06.avi',
#  'v_JumpRope_g11_c04.avi',
#  'v_HighJump_g04_c04.avi',
#  'v_BabyCrawling_g25_c01.avi',
#  'v_JavelinThrow_g11_c04.avi',
#  'v_HeadMassage_g02_c02.avi',
#  'v_PlayingDaf_g10_c04.avi',
#  'v_Mixing_g15_c01.avi',
#  'v_GolfSwing_g11_c05.avi',
#  'v_HorseRiding_g11_c03.avi',
#  'v_HorseRiding_g12_c05.avi',
#  'v_LongJump_g25_c01.avi',
#  'v_FloorGymnastics_g17_c05.avi',
#  'v_JumpingJack_g15_c02.avi',
#  'v_PlayingFlute_g15_c03.avi',
#  'v_ApplyLipstick_g01_c05.avi',
#  'v_PlayingCello_g16_c01.avi',
#  'v_LongJump_g02_c02.avi',
#  'v_HorseRiding_g05_c07.avi',
#  'v_BaseballPitch_g25_c06.avi',
#  'v_Mixing_g14_c07.avi',
#  'v_HammerThrow_g06_c01.avi',
#  'v_HulaHoop_g05_c03.avi',
#  'v_CuttingInKitchen_g23_c04.avi',
#  'v_ApplyEyeMakeup_g17_c05.avi',
#  'v_ParallelBars_g13_c04.avi',
#  'v_Diving_g02_c04.avi',
#  'v_JumpRope_g01_c02.avi',
#  'v_PlayingFlute_g04_c04.avi',
#  'v_BlowDryHair_g23_c01.avi',
#  'v_BoxingPunchingBag_g17_c03.avi',
#  'v_PlayingSitar_g10_c04.avi',
#  'v_JavelinThrow_g05_c06.avi',
#  'v_JugglingBalls_g13_c02.avi',
#  'v_Basketball_g21_c05.avi',
#  'v_Billiards_g10_c05.avi',
#  'v_BoxingPunchingBag_g07_c04.avi',
#  'v_HorseRace_g11_c01.avi',
#  'v_BalanceBeam_g04_c01.avi',
#  'v_Basketball_g01_c01.avi',
#  'v_CleanAndJerk_g21_c01.avi',
#  'v_Fencing_g06_c04.avi',
#  'v_HorseRiding_g04_c05.avi',
#  'v_BaseballPitch_g22_c06.avi',
#  'v_PlayingPiano_g24_c03.avi',
#  'v_MoppingFloor_g05_c03.avi',
#  'v_Haircut_g02_c03.avi',
#  'v_HandstandPushups_g15_c04.avi',
#  'v_PlayingDhol_g12_c01.avi',
#  'v_PlayingCello_g10_c05.avi',
#  'v_HulaHoop_g19_c04.avi',
#  'v_Hammering_g03_c03.avi',
#  'v_HulaHoop_g25_c02.avi',
#  'v_FrisbeeCatch_g10_c01.avi',
#  'v_Basketball_g17_c04.avi',
#  'v_BandMarching_g10_c05.avi',
#  'v_JugglingBalls_g10_c02.avi',
#  'v_ApplyEyeMakeup_g01_c01.avi',
#  'v_BandMarching_g02_c01.avi',
#  'v_PlayingGuitar_g20_c05.avi',
#  'v_JumpingJack_g14_c02.avi',
#  'v_PlayingGuitar_g11_c06.avi',
#  'v_HorseRiding_g23_c04.avi',
#  'v_PizzaTossing_g06_c05.avi',
#  'v_CliffDiving_g23_c03.avi',
#  'v_MilitaryParade_g09_c03.avi',
#  'v_BabyCrawling_g13_c06.avi',
#  'v_HeadMassage_g15_c02.avi',
#  'v_BabyCrawling_g01_c04.avi',
#  'v_ApplyLipstick_g17_c05.avi',
#  'v_PlayingPiano_g21_c02.avi',
#  'v_Basketball_g04_c02.avi',
#  'v_ApplyEyeMakeup_g05_c03.avi',
#  'v_FrontCrawl_g25_c01.avi',
#  'v_Haircut_g19_c04.avi',
#  'v_Hammering_g07_c04.avi',
#  'v_CricketShot_g18_c01.avi',
#  'v_HulaHoop_g06_c04.avi',
#  'v_Billiards_g09_c06.avi',
#  'v_LongJump_g01_c07.avi',
#  'v_ParallelBars_g11_c05.avi',
#  'v_HorseRace_g20_c03.avi',
#  'v_Bowling_g04_c03.avi',
#  'v_HandstandWalking_g12_c01.avi',
#  'v_HandstandWalking_g13_c02.avi',
#  'v_BenchPress_g12_c06.avi',
#  'v_Kayaking_g03_c01.avi',
#  'v_HulaHoop_g17_c05.avi',
#  'v_MilitaryParade_g15_c03.avi',
#  'v_BrushingTeeth_g25_c03.avi',
#  'v_CliffDiving_g13_c02.avi',
#  'v_ApplyLipstick_g22_c03.avi',
#  'v_Lunges_g10_c04.avi',
#  'v_MoppingFloor_g05_c01.avi',
#  'v_Mixing_g11_c02.avi',
#  'v_PlayingPiano_g24_c01.avi',
#  'v_HammerThrow_g14_c06.avi',
#  'v_JugglingBalls_g04_c05.avi',
#  'v_Kayaking_g16_c04.avi',
#  'v_Drumming_g23_c02.avi',
#  'v_CleanAndJerk_g15_c02.avi',
#  'v_Mixing_g10_c02.avi',
#  'v_Drumming_g11_c05.avi',
#  'v_JugglingBalls_g14_c04.avi',
#  'v_BlowDryHair_g20_c01.avi',
#  'v_Archery_g07_c04.avi',
#  'v_HorseRace_g25_c02.avi',
#  'v_MoppingFloor_g21_c03.avi',
#  'v_Bowling_g20_c03.avi',
#  'v_JugglingBalls_g03_c07.avi',
#  'v_JumpRope_g17_c05.avi',
#  'v_JumpingJack_g16_c03.avi',
#  'v_BandMarching_g21_c04.avi',
#  'v_GolfSwing_g03_c06.avi',
#  'v_JumpingJack_g01_c02.avi',
#  'v_BoxingPunchingBag_g16_c03.avi',
#  'v_HulaHoop_g24_c01.avi',
#  'v_FrontCrawl_g17_c06.avi',
#  'v_Bowling_g19_c06.avi',
#  'v_Biking_g10_c01.avi',
#  'v_Drumming_g11_c02.avi',
#  'v_BaseballPitch_g07_c02.avi',
#  'v_ApplyEyeMakeup_g07_c02.avi',
#  'v_Nunchucks_g07_c04.avi',
#  'v_LongJump_g12_c03.avi',
#  'v_BlowDryHair_g16_c02.avi',
#  'v_HeadMassage_g05_c02.avi',
#  'v_ApplyLipstick_g12_c01.avi',
#  'v_Billiards_g19_c03.avi',
#  'v_HandstandWalking_g05_c06.avi',
#  'v_BrushingTeeth_g18_c06.avi',
#  'v_LongJump_g01_c02.avi',
#  'v_CuttingInKitchen_g09_c01.avi',
#  'v_FloorGymnastics_g12_c05.avi',
#  'v_HorseRiding_g15_c06.avi',
#  'v_MilitaryParade_g25_c05.avi',
#  'v_PlayingCello_g12_c07.avi',
#  'v_ApplyEyeMakeup_g01_c04.avi',
#  'v_HighJump_g03_c04.avi',
#  'v_JavelinThrow_g04_c03.avi',
#  'v_Billiards_g13_c04.avi',
#  'v_JugglingBalls_g09_c06.avi',
#  'v_CuttingInKitchen_g03_c04.avi',
#  'v_CricketShot_g13_c07.avi',
#  'v_Hammering_g24_c04.avi',
#  'v_Haircut_g19_c06.avi',
#  'v_Billiards_g04_c03.avi',
#  'v_PlayingCello_g04_c01.avi',
#  'v_HighJump_g15_c01.avi',
#  'v_PlayingDhol_g20_c01.avi',
#  'v_Nunchucks_g01_c02.avi',
#  'v_JumpRope_g09_c03.avi',
#  'v_BabyCrawling_g13_c04.avi',
#  'v_Haircut_g04_c01.avi',
#  'v_HandstandPushups_g18_c05.avi',
#  'v_BoxingSpeedBag_g14_c01.avi',
#  'v_HandstandPushups_g16_c07.avi',
#  'v_BoxingPunchingBag_g24_c01.avi',
#  'v_PlayingDhol_g14_c06.avi',
#  'v_GolfSwing_g17_c07.avi',
#  'v_IceDancing_g20_c05.avi',
#  'v_GolfSwing_g22_c05.avi',
#  'v_BreastStroke_g14_c01.avi',
#  'v_IceDancing_g17_c01.avi',
#  'v_BodyWeightSquats_g15_c01.avi',
#  'v_Lunges_g21_c02.avi',
#  'v_BabyCrawling_g17_c01.avi',
#  'v_BodyWeightSquats_g17_c04.avi',
#  'v_FloorGymnastics_g11_c03.avi',
#  'v_CleanAndJerk_g06_c03.avi',
#  'v_MilitaryParade_g03_c04.avi',
#  'v_BoxingPunchingBag_g15_c06.avi',
#  'v_BreastStroke_g23_c02.avi',
#  'v_Hammering_g17_c02.avi',
#  'v_CliffDiving_g07_c05.avi',
#  'v_CuttingInKitchen_g24_c02.avi',
#  'v_Lunges_g14_c07.avi',
#  'v_HorseRace_g14_c01.avi',
#  'v_BaseballPitch_g09_c02.avi',
#  'v_CricketBowling_g07_c04.avi',
#  'v_PlayingPiano_g16_c04.avi',
#  'v_HorseRace_g07_c06.avi',
#  'v_CricketShot_g13_c03.avi',
#  'v_HorseRace_g22_c01.avi',
#  'v_Lunges_g06_c06.avi',
#  'v_CliffDiving_g15_c02.avi',
#  'v_PlayingDaf_g09_c01.avi',
#  'v_BrushingTeeth_g08_c01.avi',
#  'v_Knitting_g03_c03.avi',
#  'v_CuttingInKitchen_g12_c04.avi',
#  'v_Archery_g02_c02.avi',
#  'v_BlowingCandles_g18_c02.avi',
#  'v_GolfSwing_g18_c03.avi',
#  'v_HandstandPushups_g18_c02.avi',
#  'v_FrisbeeCatch_g24_c02.avi',
#  'v_Basketball_g23_c06.avi',
#  'v_Biking_g17_c02.avi',
#  'v_Haircut_g07_c04.avi',
#  'v_Haircut_g09_c03.avi',
#  'v_CliffDiving_g10_c03.avi',
#  'v_FrisbeeCatch_g16_c06.avi',
#  'v_FloorGymnastics_g19_c01.avi',
#  'v_HulaHoop_g17_c02.avi',
#  'v_BrushingTeeth_g19_c04.avi',
#  'v_JumpingJack_g09_c02.avi',
#  'v_GolfSwing_g19_c04.avi',
#  'v_Nunchucks_g06_c01.avi',
#  'v_Knitting_g18_c04.avi',
#  'v_PlayingDhol_g06_c03.avi',
#  'v_BandMarching_g14_c05.avi',
#  'v_FrisbeeCatch_g07_c03.avi',
#  'v_BandMarching_g17_c03.avi',
#  'v_HeadMassage_g24_c02.avi',
#  'v_Archery_g11_c03.avi',
#  'v_Drumming_g24_c05.avi',
#  'v_BlowDryHair_g24_c02.avi',
#  'v_Diving_g14_c04.avi',
#  'v_FrisbeeCatch_g07_c02.avi',
#  'v_CleanAndJerk_g24_c04.avi',
#  'v_HulaHoop_g22_c01.avi',
#  'v_PlayingCello_g18_c02.avi',
#  'v_FrontCrawl_g07_c03.avi',
#  'v_BasketballDunk_g02_c01.avi',
#  'v_HeadMassage_g01_c04.avi',
#  'v_FrontCrawl_g05_c01.avi',
#  'v_PlayingFlute_g05_c03.avi',
#  'v_Biking_g18_c05.avi',
#  'v_BandMarching_g11_c04.avi',
#  'v_MoppingFloor_g04_c06.avi',
#  'v_Knitting_g01_c04.avi',
#  'v_CricketShot_g03_c06.avi',
#  'v_CliffDiving_g05_c02.avi',
#  'v_Biking_g25_c04.avi',
#  'v_Billiards_g15_c02.avi',
#  'v_Kayaking_g13_c01.avi',
#  'v_Kayaking_g18_c02.avi',
#  'v_HandstandWalking_g10_c03.avi',
#  'v_Biking_g02_c03.avi',
#  'v_BandMarching_g01_c02.avi',
#  'v_HulaHoop_g09_c04.avi',
#  'v_HandstandWalking_g08_c03.avi',
#  'v_Diving_g03_c07.avi',
#  'v_Diving_g24_c06.avi',
#  'v_HandstandPushups_g23_c04.avi',
#  'v_CliffDiving_g20_c01.avi',
#  'v_PizzaTossing_g02_c05.avi',
#  'v_Biking_g23_c02.avi',
#  'v_BoxingPunchingBag_g12_c02.avi',
#  'v_JavelinThrow_g03_c03.avi',
#  'v_HandstandWalking_g08_c04.avi',
#  'v_Hammering_g24_c02.avi',
#  'v_CricketShot_g20_c03.avi',
#  'v_PlayingFlute_g06_c02.avi',
#  'v_BoxingPunchingBag_g25_c02.avi',
#  'v_CricketBowling_g25_c05.avi',
#  'v_PlayingFlute_g07_c05.avi',
#  'v_BaseballPitch_g06_c04.avi',
#  'v_HighJump_g07_c04.avi',
#  'v_ApplyEyeMakeup_g11_c03.avi',
#  'v_FloorGymnastics_g18_c02.avi',
#  'v_CricketBowling_g16_c03.avi',
#  'v_Haircut_g19_c02.avi',
#  'v_CuttingInKitchen_g13_c01.avi',
#  'v_PlayingCello_g02_c04.avi',
#  'v_Biking_g14_c02.avi',
#  'v_BaseballPitch_g16_c06.avi',
#  'v_BandMarching_g23_c03.avi',
#  'v_PlayingDaf_g04_c02.avi',
#  'v_JumpingJack_g25_c07.avi',
#  'v_PlayingCello_g02_c01.avi',
#  'v_Hammering_g19_c05.avi',
#  'v_BalanceBeam_g07_c03.avi',
#  'v_IceDancing_g24_c02.avi',
#  'v_ParallelBars_g08_c04.avi',
#  'v_Hammering_g19_c04.avi',
#  'v_FieldHockeyPenalty_g23_c03.avi',
#  'v_PlayingGuitar_g21_c04.avi',
#  'v_CuttingInKitchen_g13_c03.avi',
#  'v_HighJump_g15_c04.avi',
#  'v_HandstandWalking_g13_c04.avi',
#  'v_JumpRope_g22_c05.avi',
#  'v_CleanAndJerk_g07_c05.avi',
#  'v_Knitting_g02_c02.avi',
#  'v_Diving_g23_c06.avi',
#  'v_Lunges_g11_c04.avi',
#  'v_Fencing_g01_c05.avi',
#  'v_BoxingSpeedBag_g19_c01.avi',
#  'v_BoxingSpeedBag_g22_c03.avi',
#  'v_HandstandPushups_g06_c03.avi',
#  'v_PlayingSitar_g11_c03.avi',
#  'v_Biking_g16_c03.avi',
#  'v_HeadMassage_g10_c04.avi',
#  'v_IceDancing_g23_c04.avi',
#  'v_PlayingGuitar_g20_c04.avi',
#  'v_PizzaTossing_g07_c03.avi',
#  'v_BalanceBeam_g06_c04.avi',
#  'v_MoppingFloor_g02_c05.avi',
#  'v_JumpRope_g17_c04.avi',
#  'v_LongJump_g25_c04.avi',
#  'v_HulaHoop_g18_c01.avi',
#  'v_BlowDryHair_g23_c07.avi',
#  'v_BoxingSpeedBag_g16_c01.avi',
#  'v_BreastStroke_g25_c04.avi',
#  'v_PlayingFlute_g05_c04.avi',
#  'v_PlayingFlute_g02_c07.avi',
#  'v_CuttingInKitchen_g23_c03.avi',
#  'v_Biking_g09_c03.avi',
#  'v_Bowling_g05_c01.avi',
#  'v_PlayingSitar_g23_c06.avi',
#  'v_Lunges_g19_c05.avi',
#  'v_Haircut_g12_c03.avi',
#  'v_BandMarching_g16_c03.avi',
#  'v_Archery_g22_c02.avi',
#  'v_Fencing_g04_c01.avi',
#  'v_PlayingPiano_g17_c02.avi',
#  'v_BasketballDunk_g03_c05.avi',
#  ...]

# %%
len(files)
# Out:
# 8741

# %%
def get_UCF_classname(filename):
  #print()
  return filename[filename.find('_') + 1:filename.find('_', 2)]

# %%
width, height, depth = 32, 32, 20
channel = 1

# %%
import cv2
import numpy as np

def video3d(filename, color=False, skip=True):
  cap = cv2.VideoCapture(filename)
  #count the total number of frames
  nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
  print(nframe)
  if skip:
    frames = [x * nframe / depth for x in range(depth)]
  else:
    frames = [x for x in range(depth)]
  framearray = []

  for i in range(depth):
      #extract a specific frame out of the video
      cap.set(cv2.CAP_PROP_POS_FRAMES, frames[i])
      ret, frame = cap.read()
      frame = cv2.resize(frame, (height,width))
      if color:
          framearray.append(frame)
      else:
          gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
          gray = gray.reshape(gray.shape[0],gray.shape[1],1)
          framearray.append(gray)

  cap.release()
  print(np.array(framearray).shape)
  return np.array(framearray)

# %%
video_dir="/content/UCF101"
nclass=5
for filename in files:
  name = os.path.join(video_dir, filename)
  label = get_UCF_classname(filename)
  if label not in labellist:
    if len(labellist) >= nclass:
      continue
    labellist.append(label)
  labels.append(label)
  X.append(video3d(name, color=False, skip=True))
# Out:
# 116.0
# (20, 32, 32, 1)
# 243.0
# (20, 32, 32, 1)
# 216.0
# (20, 32, 32, 1)
# 75.0
# (20, 32, 32, 1)
# 525.0
# (20, 32, 32, 1)
# 352.0
# (20, 32, 32, 1)
# 526.0
# (20, 32, 32, 1)
# 497.0
# (20, 32, 32, 1)
# 157.0
# (20, 32, 32, 1)
# 193.0
# (20, 32, 32, 1)
# 485.0
# (20, 32, 32, 1)
# 305.0
# (20, 32, 32, 1)
# 183.0
# (20, 32, 32, 1)
# 85.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 94.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 294.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 374.0
# (20, 32, 32, 1)
# 98.0
# (20, 32, 32, 1)
# 73.0
# (20, 32, 32, 1)
# 290.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 88.0
# (20, 32, 32, 1)
# 507.0
# (20, 32, 32, 1)
# 124.0
# (20, 32, 32, 1)
# 491.0
# (20, 32, 32, 1)
# 398.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 380.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 105.0
# (20, 32, 32, 1)
# 87.0
# (20, 32, 32, 1)
# 356.0
# (20, 32, 32, 1)
# 388.0
# (20, 32, 32, 1)
# 307.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 59.0
# (20, 32, 32, 1)
# 163.0
# (20, 32, 32, 1)
# 462.0
# (20, 32, 32, 1)
# 358.0
# (20, 32, 32, 1)
# 125.0
# (20, 32, 32, 1)
# 219.0
# (20, 32, 32, 1)
# 501.0
# (20, 32, 32, 1)
# 406.0
# (20, 32, 32, 1)
# 622.0
# (20, 32, 32, 1)
# 131.0
# (20, 32, 32, 1)
# 77.0
# (20, 32, 32, 1)
# 518.0
# (20, 32, 32, 1)
# 268.0
# (20, 32, 32, 1)
# 136.0
# (20, 32, 32, 1)
# 575.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 500.0
# (20, 32, 32, 1)
# 112.0
# (20, 32, 32, 1)
# 80.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 118.0
# (20, 32, 32, 1)
# 140.0
# (20, 32, 32, 1)
# 121.0
# (20, 32, 32, 1)
# 56.0
# (20, 32, 32, 1)
# 209.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 599.0
# (20, 32, 32, 1)
# 169.0
# (20, 32, 32, 1)
# 189.0
# (20, 32, 32, 1)
# 100.0
# (20, 32, 32, 1)
# 174.0
# (20, 32, 32, 1)
# 167.0
# (20, 32, 32, 1)
# 619.0
# (20, 32, 32, 1)
# 100.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 528.0
# (20, 32, 32, 1)
# 618.0
# (20, 32, 32, 1)
# 437.0
# (20, 32, 32, 1)
# 391.0
# (20, 32, 32, 1)
# 200.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 78.0
# (20, 32, 32, 1)
# 197.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 243.0
# (20, 32, 32, 1)
# 90.0
# (20, 32, 32, 1)
# 70.0
# (20, 32, 32, 1)
# 466.0
# (20, 32, 32, 1)
# 346.0
# (20, 32, 32, 1)
# 476.0
# (20, 32, 32, 1)
# 504.0
# (20, 32, 32, 1)
# 52.0
# (20, 32, 32, 1)
# 75.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 378.0
# (20, 32, 32, 1)
# 153.0
# (20, 32, 32, 1)
# 105.0
# (20, 32, 32, 1)
# 61.0
# (20, 32, 32, 1)
# 209.0
# (20, 32, 32, 1)
# 126.0
# (20, 32, 32, 1)
# 83.0
# (20, 32, 32, 1)
# 190.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 50.0
# (20, 32, 32, 1)
# 480.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 98.0
# (20, 32, 32, 1)
# 381.0
# (20, 32, 32, 1)
# 162.0
# (20, 32, 32, 1)
# 300.0
# (20, 32, 32, 1)
# 118.0
# (20, 32, 32, 1)
# 52.0
# (20, 32, 32, 1)
# 432.0
# (20, 32, 32, 1)
# 243.0
# (20, 32, 32, 1)
# 150.0
# (20, 32, 32, 1)
# 103.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 167.0
# (20, 32, 32, 1)
# 236.0
# (20, 32, 32, 1)
# 99.0
# (20, 32, 32, 1)
# 84.0
# (20, 32, 32, 1)
# 402.0
# (20, 32, 32, 1)
# 68.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 204.0
# (20, 32, 32, 1)
# 47.0
# (20, 32, 32, 1)
# 391.0
# (20, 32, 32, 1)
# 257.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 64.0
# (20, 32, 32, 1)
# 458.0
# (20, 32, 32, 1)
# 168.0
# (20, 32, 32, 1)
# 589.0
# (20, 32, 32, 1)
# 254.0
# (20, 32, 32, 1)
# 601.0
# (20, 32, 32, 1)
# 230.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 354.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 518.0
# (20, 32, 32, 1)
# 496.0
# (20, 32, 32, 1)
# 350.0
# (20, 32, 32, 1)
# 98.0
# (20, 32, 32, 1)
# 95.0
# (20, 32, 32, 1)
# 230.0
# (20, 32, 32, 1)
# 226.0
# (20, 32, 32, 1)
# 89.0
# (20, 32, 32, 1)
# 93.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 157.0
# (20, 32, 32, 1)
# 127.0
# (20, 32, 32, 1)
# 76.0
# (20, 32, 32, 1)
# 100.0
# (20, 32, 32, 1)
# 222.0
# (20, 32, 32, 1)
# 300.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 445.0
# (20, 32, 32, 1)
# 299.0
# (20, 32, 32, 1)
# 206.0
# (20, 32, 32, 1)
# 426.0
# (20, 32, 32, 1)
# 509.0
# (20, 32, 32, 1)
# 116.0
# (20, 32, 32, 1)
# 450.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 334.0
# (20, 32, 32, 1)
# 471.0
# (20, 32, 32, 1)
# 192.0
# (20, 32, 32, 1)
# 181.0
# (20, 32, 32, 1)
# 305.0
# (20, 32, 32, 1)
# 306.0
# (20, 32, 32, 1)
# 87.0
# (20, 32, 32, 1)
# 90.0
# (20, 32, 32, 1)
# 77.0
# (20, 32, 32, 1)
# 403.0
# (20, 32, 32, 1)
# 152.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 196.0
# (20, 32, 32, 1)
# 129.0
# (20, 32, 32, 1)
# 336.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 83.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 164.0
# (20, 32, 32, 1)
# 221.0
# (20, 32, 32, 1)
# 90.0
# (20, 32, 32, 1)
# 345.0
# (20, 32, 32, 1)
# 624.0
# (20, 32, 32, 1)
# 239.0
# (20, 32, 32, 1)
# 417.0
# (20, 32, 32, 1)
# 380.0
# (20, 32, 32, 1)
# 106.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 112.0
# (20, 32, 32, 1)
# 46.0
# (20, 32, 32, 1)
# 416.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 102.0
# (20, 32, 32, 1)
# 97.0
# (20, 32, 32, 1)
# 250.0
# (20, 32, 32, 1)
# 366.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 61.0
# (20, 32, 32, 1)
# 491.0
# (20, 32, 32, 1)
# 99.0
# (20, 32, 32, 1)
# 403.0
# (20, 32, 32, 1)
# 491.0
# (20, 32, 32, 1)
# 411.0
# (20, 32, 32, 1)
# 451.0
# (20, 32, 32, 1)
# 101.0
# (20, 32, 32, 1)
# 346.0
# (20, 32, 32, 1)
# 61.0
# (20, 32, 32, 1)
# 300.0
# (20, 32, 32, 1)
# 133.0
# (20, 32, 32, 1)
# 248.0
# (20, 32, 32, 1)
# 305.0
# (20, 32, 32, 1)
# 492.0
# (20, 32, 32, 1)
# 405.0
# (20, 32, 32, 1)
# 88.0
# (20, 32, 32, 1)
# 136.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 138.0
# (20, 32, 32, 1)
# 430.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 52.0
# (20, 32, 32, 1)
# 91.0
# (20, 32, 32, 1)
# 164.0
# (20, 32, 32, 1)
# 623.0
# (20, 32, 32, 1)
# 605.0
# (20, 32, 32, 1)
# 152.0
# (20, 32, 32, 1)
# 620.0
# (20, 32, 32, 1)
# 437.0
# (20, 32, 32, 1)
# 84.0
# (20, 32, 32, 1)
# 509.0
# (20, 32, 32, 1)
# 209.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 343.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 138.0
# (20, 32, 32, 1)
# 85.0
# (20, 32, 32, 1)
# 191.0
# (20, 32, 32, 1)
# 464.0
# (20, 32, 32, 1)
# 68.0
# (20, 32, 32, 1)
# 76.0
# (20, 32, 32, 1)
# 68.0
# (20, 32, 32, 1)
# 135.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 489.0
# (20, 32, 32, 1)
# 58.0
# (20, 32, 32, 1)
# 332.0
# (20, 32, 32, 1)
# 63.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 391.0
# (20, 32, 32, 1)
# 35.0
# (20, 32, 32, 1)
# 510.0
# (20, 32, 32, 1)
# 136.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 250.0
# (20, 32, 32, 1)
# 303.0
# (20, 32, 32, 1)
# 181.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 55.0
# (20, 32, 32, 1)
# 56.0
# (20, 32, 32, 1)
# 141.0
# (20, 32, 32, 1)
# 247.0
# (20, 32, 32, 1)
# 459.0
# (20, 32, 32, 1)
# 53.0
# (20, 32, 32, 1)
# 147.0
# (20, 32, 32, 1)
# 97.0
# (20, 32, 32, 1)
# 57.0
# (20, 32, 32, 1)
# 51.0
# (20, 32, 32, 1)
# 507.0
# (20, 32, 32, 1)
# 203.0
# (20, 32, 32, 1)
# 340.0
# (20, 32, 32, 1)
# 91.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 85.0
# (20, 32, 32, 1)
# 364.0
# (20, 32, 32, 1)
# 96.0
# (20, 32, 32, 1)
# 298.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 233.0
# (20, 32, 32, 1)
# 110.0
# (20, 32, 32, 1)
# 340.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 75.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 80.0
# (20, 32, 32, 1)
# 85.0
# (20, 32, 32, 1)
# 134.0
# (20, 32, 32, 1)
# 58.0
# (20, 32, 32, 1)
# 139.0
# (20, 32, 32, 1)
# 91.0
# (20, 32, 32, 1)
# 488.0
# (20, 32, 32, 1)
# 95.0
# (20, 32, 32, 1)
# 53.0
# (20, 32, 32, 1)
# 51.0
# (20, 32, 32, 1)
# 403.0
# (20, 32, 32, 1)
# 69.0
# (20, 32, 32, 1)
# 178.0
# (20, 32, 32, 1)
# 536.0
# (20, 32, 32, 1)
# 461.0
# (20, 32, 32, 1)
# 133.0
# (20, 32, 32, 1)
# 283.0
# (20, 32, 32, 1)
# 244.0
# (20, 32, 32, 1)
# 132.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 78.0
# (20, 32, 32, 1)
# 85.0
# (20, 32, 32, 1)
# 117.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 93.0
# (20, 32, 32, 1)
# 213.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 249.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 141.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 476.0
# (20, 32, 32, 1)
# 108.0
# (20, 32, 32, 1)
# 450.0
# (20, 32, 32, 1)
# 498.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 146.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 298.0
# (20, 32, 32, 1)
# 100.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 224.0
# (20, 32, 32, 1)
# 204.0
# (20, 32, 32, 1)
# 489.0
# (20, 32, 32, 1)
# 236.0
# (20, 32, 32, 1)
# 37.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 102.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 213.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 78.0
# (20, 32, 32, 1)
# 209.0
# (20, 32, 32, 1)
# 233.0
# (20, 32, 32, 1)
# 358.0
# (20, 32, 32, 1)
# 490.0
# (20, 32, 32, 1)
# 599.0
# (20, 32, 32, 1)
# 614.0
# (20, 32, 32, 1)
# 343.0
# (20, 32, 32, 1)
# 95.0
# (20, 32, 32, 1)
# 155.0
# (20, 32, 32, 1)
# 102.0
# (20, 32, 32, 1)
# 237.0
# (20, 32, 32, 1)
# 81.0
# (20, 32, 32, 1)
# 116.0
# (20, 32, 32, 1)
# 131.0
# (20, 32, 32, 1)
# 123.0
# (20, 32, 32, 1)
# 163.0
# (20, 32, 32, 1)
# 153.0
# (20, 32, 32, 1)
# 93.0
# (20, 32, 32, 1)
# 136.0
# (20, 32, 32, 1)
# 59.0
# (20, 32, 32, 1)
# 81.0
# (20, 32, 32, 1)
# 529.0
# (20, 32, 32, 1)
# 125.0
# (20, 32, 32, 1)
# 243.0
# (20, 32, 32, 1)
# 76.0
# (20, 32, 32, 1)
# 76.0
# (20, 32, 32, 1)
# 120.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 387.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 95.0
# (20, 32, 32, 1)
# 472.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 137.0
# (20, 32, 32, 1)
# 76.0
# (20, 32, 32, 1)
# 145.0
# (20, 32, 32, 1)
# 500.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 391.0
# (20, 32, 32, 1)
# 483.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 91.0
# (20, 32, 32, 1)
# 109.0
# (20, 32, 32, 1)
# 181.0
# (20, 32, 32, 1)
# 246.0
# (20, 32, 32, 1)
# 289.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 112.0
# (20, 32, 32, 1)
# 228.0
# (20, 32, 32, 1)
# 447.0
# (20, 32, 32, 1)
# 531.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 57.0
# (20, 32, 32, 1)
# 410.0
# (20, 32, 32, 1)
# 355.0
# (20, 32, 32, 1)
# 492.0
# (20, 32, 32, 1)
# 275.0
# (20, 32, 32, 1)
# 389.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 250.0
# (20, 32, 32, 1)
# 400.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 125.0
# (20, 32, 32, 1)
# 67.0
# (20, 32, 32, 1)
# 250.0
# (20, 32, 32, 1)
# 316.0
# (20, 32, 32, 1)
# 163.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 120.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 70.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 503.0
# (20, 32, 32, 1)
# 77.0
# (20, 32, 32, 1)
# 250.0
# (20, 32, 32, 1)
# 482.0
# (20, 32, 32, 1)
# 228.0
# (20, 32, 32, 1)
# 175.0
# (20, 32, 32, 1)
# 99.0
# (20, 32, 32, 1)
# 144.0
# (20, 32, 32, 1)
# 495.0
# (20, 32, 32, 1)
# 111.0
# (20, 32, 32, 1)
# 96.0
# (20, 32, 32, 1)
# 61.0
# (20, 32, 32, 1)
# 483.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 89.0
# (20, 32, 32, 1)
# 53.0
# (20, 32, 32, 1)
# 48.0
# (20, 32, 32, 1)
# 166.0
# (20, 32, 32, 1)
# 70.0
# (20, 32, 32, 1)
# 164.0
# (20, 32, 32, 1)
# 335.0
# (20, 32, 32, 1)
# 225.0
# (20, 32, 32, 1)
# 410.0
# (20, 32, 32, 1)
# 223.0
# (20, 32, 32, 1)
# 51.0
# (20, 32, 32, 1)
# 360.0
# (20, 32, 32, 1)
# 126.0
# (20, 32, 32, 1)
# 380.0
# (20, 32, 32, 1)
# 358.0
# (20, 32, 32, 1)
# 57.0
# (20, 32, 32, 1)
# 482.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 533.0
# (20, 32, 32, 1)
# 113.0
# (20, 32, 32, 1)
# 61.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 212.0
# (20, 32, 32, 1)
# 155.0
# (20, 32, 32, 1)
# 510.0
# (20, 32, 32, 1)
# 510.0
# (20, 32, 32, 1)
# 108.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 81.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 446.0
# (20, 32, 32, 1)
# 436.0
# (20, 32, 32, 1)
# 422.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 101.0
# (20, 32, 32, 1)
# 416.0
# (20, 32, 32, 1)
# 84.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 115.0
# (20, 32, 32, 1)
# 79.0
# (20, 32, 32, 1)
# 91.0
# (20, 32, 32, 1)
# 548.0
# (20, 32, 32, 1)
# 79.0
# (20, 32, 32, 1)
# 479.0
# (20, 32, 32, 1)
# 210.0
# (20, 32, 32, 1)
# 214.0
# (20, 32, 32, 1)
# 107.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 67.0
# (20, 32, 32, 1)
# 60.0
# (20, 32, 32, 1)
# 197.0
# (20, 32, 32, 1)
# 124.0
# (20, 32, 32, 1)
# 168.0
# (20, 32, 32, 1)
# 146.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 398.0
# (20, 32, 32, 1)
# 75.0
# (20, 32, 32, 1)
# 75.0
# (20, 32, 32, 1)
# 57.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 294.0
# (20, 32, 32, 1)
# 51.0
# (20, 32, 32, 1)
# 313.0
# (20, 32, 32, 1)
# 171.0
# (20, 32, 32, 1)
# 452.0
# (20, 32, 32, 1)
# 56.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 243.0
# (20, 32, 32, 1)
# 377.0
# (20, 32, 32, 1)
# 300.0
# (20, 32, 32, 1)
# 69.0
# (20, 32, 32, 1)
# 113.0
# (20, 32, 32, 1)
# 599.0
# (20, 32, 32, 1)
# 101.0
# (20, 32, 32, 1)
# 195.0
# (20, 32, 32, 1)
# 116.0
# (20, 32, 32, 1)
# 356.0
# (20, 32, 32, 1)
# 123.0
# (20, 32, 32, 1)
# 84.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 546.0
# (20, 32, 32, 1)
# 79.0
# (20, 32, 32, 1)
# 204.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 605.0
# (20, 32, 32, 1)
# 408.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 68.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 510.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 203.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 62.0
# (20, 32, 32, 1)
# 199.0
# (20, 32, 32, 1)
# 81.0
# (20, 32, 32, 1)
# 53.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 374.0
# (20, 32, 32, 1)
# 453.0
# (20, 32, 32, 1)
# 207.0
# (20, 32, 32, 1)
# 223.0
# (20, 32, 32, 1)
# 235.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 539.0
# (20, 32, 32, 1)
# 358.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 198.0
# (20, 32, 32, 1)
# 63.0
# (20, 32, 32, 1)
# 131.0
# (20, 32, 32, 1)
# 502.0
# (20, 32, 32, 1)
# 53.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 408.0
# (20, 32, 32, 1)
# 366.0
# (20, 32, 32, 1)
# 310.0
# (20, 32, 32, 1)
# 101.0
# (20, 32, 32, 1)
# 68.0
# (20, 32, 32, 1)
# 296.0
# (20, 32, 32, 1)
# 58.0
# (20, 32, 32, 1)
# 486.0
# (20, 32, 32, 1)
# 527.0
# (20, 32, 32, 1)
# 252.0
# (20, 32, 32, 1)
# 91.0
# (20, 32, 32, 1)
# 443.0
# (20, 32, 32, 1)
# 74.0
# (20, 32, 32, 1)
# 384.0
# (20, 32, 32, 1)
# 42.0
# (20, 32, 32, 1)
# 112.0
# (20, 32, 32, 1)
# 61.0
# (20, 32, 32, 1)
# 539.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 99.0
# (20, 32, 32, 1)
# 109.0
# (20, 32, 32, 1)
# 106.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 124.0
# (20, 32, 32, 1)
# 65.0
# (20, 32, 32, 1)
# 382.0
# (20, 32, 32, 1)
# 135.0
# (20, 32, 32, 1)
# 105.0
# (20, 32, 32, 1)
# 81.0
# (20, 32, 32, 1)
# 251.0
# (20, 32, 32, 1)
# 152.0
# (20, 32, 32, 1)
# 475.0
# (20, 32, 32, 1)
# 299.0
# (20, 32, 32, 1)
# 445.0
# (20, 32, 32, 1)
# 132.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 396.0
# (20, 32, 32, 1)
# 501.0
# (20, 32, 32, 1)
# 571.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 199.0
# (20, 32, 32, 1)
# 88.0
# (20, 32, 32, 1)
# 275.0
# (20, 32, 32, 1)
# 97.0
# (20, 32, 32, 1)
# 69.0
# (20, 32, 32, 1)
# 495.0
# (20, 32, 32, 1)
# 66.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 408.0
# (20, 32, 32, 1)
# 380.0
# (20, 32, 32, 1)
# 77.0
# (20, 32, 32, 1)
# 283.0
# (20, 32, 32, 1)
# 67.0
# (20, 32, 32, 1)
# 79.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 127.0
# (20, 32, 32, 1)
# 500.0
# (20, 32, 32, 1)
# 69.0
# (20, 32, 32, 1)
# 84.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 242.0
# (20, 32, 32, 1)
# 65.0
# (20, 32, 32, 1)
# 80.0
# (20, 32, 32, 1)
# 110.0
# (20, 32, 32, 1)
# 129.0
# (20, 32, 32, 1)
# 236.0
# (20, 32, 32, 1)
# 73.0
# (20, 32, 32, 1)
# 72.0
# (20, 32, 32, 1)
# 148.0
# (20, 32, 32, 1)
# 138.0
# (20, 32, 32, 1)
# 93.0
# (20, 32, 32, 1)
# 201.0
# (20, 32, 32, 1)
# 80.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 51.0
# (20, 32, 32, 1)
# 109.0
# (20, 32, 32, 1)
# 125.0
# (20, 32, 32, 1)
# 400.0
# (20, 32, 32, 1)
# 109.0
# (20, 32, 32, 1)
# 64.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 151.0
# (20, 32, 32, 1)
# 537.0
# (20, 32, 32, 1)
# 180.0
# (20, 32, 32, 1)
# 77.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 70.0
# (20, 32, 32, 1)
# 526.0
# (20, 32, 32, 1)
# 82.0
# (20, 32, 32, 1)
# 448.0
# (20, 32, 32, 1)
# 293.0
# (20, 32, 32, 1)
# 131.0
# (20, 32, 32, 1)
# 533.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 246.0
# (20, 32, 32, 1)
# 315.0
# (20, 32, 32, 1)
# 122.0
# (20, 32, 32, 1)
# 240.0
# (20, 32, 32, 1)
# 360.0
# (20, 32, 32, 1)
# 496.0
# (20, 32, 32, 1)
# 125.0
# (20, 32, 32, 1)
# 207.0
# (20, 32, 32, 1)
# 126.0
# (20, 32, 32, 1)
# 94.0
# (20, 32, 32, 1)
# 59.0
# (20, 32, 32, 1)
# 510.0
# (20, 32, 32, 1)
# 71.0
# (20, 32, 32, 1)
# 86.0
# (20, 32, 32, 1)
# 58.0
# (20, 32, 32, 1)
# 219.0
# (20, 32, 32, 1)
# 67.0
# (20, 32, 32, 1)
# 324.0
# (20, 32, 32, 1)

# %%
X= np.array(X)

# %%
X.shape
# Out:
# (669, 20, 32, 32, 1)

# %%
X = np.array(X).transpose((0, 2, 3, 4, 1))

# %%
X.shape
# Out:
# (669, 32, 32, 1, 20)

# %%
with open(os.path.join('classes.txt'), 'w') as fp:
  for i in range(len(labellist)):
      fp.write('{}\n'.format(labellist[i]))
for num, label in enumerate(labellist):
    for i in range(len(labels)):
        if label == labels[i]:
            labels[i] = num

# %%
labels
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  1,
#  4,
#  4,
#  1,
#  0,
#  0,
#  2,
#  1,
#  3,
#  4,
#  2,
#  4,
#  0,
#  3,
#  1,
#  0,
#  0,
#  4,
#  1,
#  4,
#  4,
#  2,
#  2,
#  3,
#  3,
#  0,
#  2,
#  4,
#  4,
#  0,
#  2,
#  0,
#  2,
#  1,
#  2,
#  1,
#  2,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  3,
#  4,
#  2,
#  4,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  0,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  1,
#  1,
#  2,
#  4,
#  1,
#  2,
#  0,
#  4,
#  4,
#  1,
#  4,
#  1,
#  2,
#  2,
#  3,
#  1,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  4,
#  1,
#  0,
#  0,
#  2,
#  4,
#  3,
#  1,
#  0,
#  2,
#  2,
#  0,
#  1,
#  2,
#  0,
#  4,
#  3,
#  0,
#  1,
#  1,
#  1,
#  1,
#  0,
#  4,
#  1,
#  1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  0,
#  1,
#  3,
#  2,
#  2,
#  0,
#  4,
#  4,
#  2,
#  3,
#  4,
#  0,
#  4,
#  1,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  3,
#  0,
#  1,
#  1,
#  0,
#  3,
#  0,
#  2,
#  3,
#  0,
#  3,
#  1,
#  2,
#  2,
#  2,
#  4,
#  1,
#  4,
#  1,
#  4,
#  3,
#  2,
#  0,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  4,
#  0,
#  3,
#  1,
#  4,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  2,
#  1,
#  4,
#  3,
#  2,
#  4,
#  2,
#  4,
#  2,
#  0,
#  3,
#  1,
#  0,
#  4,
#  3,
#  2,
#  3,
#  3,
#  1,
#  4,
#  0,
#  3,
#  0,
#  4,
#  3,
#  4,
#  4,
#  4,
#  1,
#  3,
#  1,
#  0,
#  2,
#  1,
#  2,
#  4,
#  4,
#  4,
#  3,
#  1,
#  3,
#  3,
#  4,
#  3,
#  3,
#  0,
#  0,
#  1,
#  4,
#  4,
#  3,
#  4,
#  1,
#  3,
#  4,
#  1,
#  3,
#  2,
#  4,
#  2,
#  1,
#  3,
#  1,
#  4,
#  0,
#  0,
#  3,
#  3,
#  3,
#  4,
#  0,
#  2,
#  3,
#  2,
#  2,
#  4,
#  0,
#  4,
#  1,
#  2,
#  1,
#  1,
#  2,
#  0,
#  0,
#  0,
#  2,
#  1,
#  4,
#  0,
#  1,
#  3,
#  3,
#  0,
#  4,
#  2,
#  4,
#  3,
#  1,
#  0,
#  4,
#  3,
#  1,
#  2,
#  1,
#  3,
#  2,
#  3,
#  3,
#  2,
#  0,
#  0,
#  3,
#  0,
#  1,
#  0,
#  4,
#  0,
#  0,
#  0,
#  4,
#  0,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  0,
#  3,
#  0,
#  2,
#  3,
#  2,
#  0,
#  1,
#  3,
#  2,
#  2,
#  0,
#  4,
#  3,
#  2,
#  4,
#  1,
#  3,
#  3,
#  4,
#  3,
#  2,
#  1,
#  2,
#  4,
#  1,
#  0,
#  2,
#  0,
#  2,
#  2,
#  2,
#  2,
#  0,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  2,
#  0,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  1,
#  3,
#  3,
#  0,
#  0,
#  4,
#  0,
#  1,
#  0,
#  0,
#  3,
#  0,
#  4,
#  2,
#  3,
#  4,
#  2,
#  0,
#  3,
#  1,
#  4,
#  3,
#  2,
#  0,
#  4,
#  4,
#  0,
#  3,
#  2,
#  2,
#  1,
#  1,
#  0,
#  1,
#  1,
#  4,
#  4,
#  2,
#  0,
#  2,
#  4,
#  4,
#  1,
#  1,
#  2,
#  1,
#  2,
#  0,
#  1,
#  0,
#  1,
#  4,
#  2,
#  0,
#  1,
#  2,
#  0,
#  2,
#  4,
#  3,
#  1,
#  4,
#  1,
#  2,
#  1,
#  3,
#  4,
#  3,
#  0,
#  0,
#  1,
#  2,
#  3,
#  0,
#  0,
#  1,
#  3,
#  1,
#  4,
#  1,
#  4,
#  1,
#  0,
#  2,
#  1,
#  1,
#  4,
#  3,
#  1,
#  3,
#  4,
#  3,
#  0,
#  3,
#  4,
#  0,
#  4,
#  4,
#  3,
#  2,
#  3,
#  0,
#  1,
#  4,
#  4,
#  3,
#  1,
#  1,
#  1,
#  2,
#  0,
#  3,
#  3,
#  4,
#  0,
#  1,
#  2,
#  1,
#  3,
#  3,
#  0,
#  0,
#  0,
#  1,
#  0,
#  1,
#  3,
#  2,
#  4,
#  0,
#  3,
#  3,
#  2,
#  4,
#  0,
#  1,
#  1,
#  1,
#  0,
#  2,
#  1,
#  1,
#  2,
#  3,
#  3,
#  4,
#  2,
#  2,
#  3,
#  4,
#  2,
#  0,
#  2,
#  4,
#  3,
#  1,
#  2,
#  4,
#  4,
#  0,
#  0,
#  3,
#  4,
#  2,
#  1,
#  0,
#  0,
#  0,
#  2,
#  0,
#  0,
#  2,
#  4,
#  1,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  0,
#  2,
#  4,
#  0,
#  0,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  0,
#  4,
#  4,
#  1,
#  0,
#  4,
#  0,
#  4,
#  0,
#  3,
#  0,
#  4,
#  0,
#  3,
#  3,
#  3,
#  2,
#  1,
#  0,
#  4,
#  1,
#  0,
#  0,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  0,
#  1,
#  3,
#  3,
#  4,
#  0,
#  2,
#  4,
#  2,
#  3,
#  1,
#  0,
#  3,
#  3,
#  1,
#  4,
#  3,
#  0,
#  0,
#  4,
#  3,
#  0,
#  3,
#  1,
#  1,
#  3,
#  0,
#  0,
#  3,
#  0,
#  2,
#  0,
#  2,
#  0,
#  3,
#  1,
#  4,
#  0,
#  0,
#  2,
#  2,
#  4,
#  2,
#  0,
#  2,
#  0,
#  4,
#  0,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  3,
#  3,
#  0,
#  4,
#  3,
#  3,
#  0,
#  1,
#  0,
#  2]

# %%
#from sklearn.cross_validation import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution3D, MaxPooling3D
from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,MaxPooling3D)
from keras.utils import np_utils

# %%
Y = np_utils.to_categorical(labels,nclass)

X = X.astype('float32')
print('X_shape:{}\nY_shape:{}'.format(X.shape, Y.shape))
# Out:
# X_shape:(669, 32, 32, 1, 20)
# Y_shape:(669, 5)

# %%
model = Sequential()
model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(X.shape[1:]), padding='same'))
model.add(Activation('relu'))
model.add(Conv3D(32, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('softmax'))
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
model.add(Dropout(0.25))

model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('softmax'))
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(nclass, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 32, 32, 1, 32)     17312
#
#  activation (Activation)     (None, 32, 32, 1, 32)     0
#
#  conv3d_1 (Conv3D)           (None, 32, 32, 1, 32)     27680
#
#  activation_1 (Activation)   (None, 32, 32, 1, 32)     0
#
#  max_pooling3d (MaxPooling3D  (None, 11, 11, 1, 32)    0
#  )
#
#  dropout (Dropout)           (None, 11, 11, 1, 32)     0
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 1, 64)     55360
#
#  activation_2 (Activation)   (None, 11, 11, 1, 64)     0
#
#  conv3d_3 (Conv3D)           (None, 11, 11, 1, 64)     110656
#
#  activation_3 (Activation)   (None, 11, 11, 1, 64)     0
#
#  max_pooling3d_1 (MaxPooling  (None, 4, 4, 1, 64)      0
#  3D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 1, 64)       0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 738,373
# Trainable params: 738,373
# Non-trainable params: 0
# _________________________________________________________________

# %%
 from sklearn.model_selection import train_test_split
 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=4)

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=128,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 4s 115ms/step - loss: 1.8198 - accuracy: 0.1888 - val_loss: 1.6454 - val_accuracy: 0.1493
# Epoch 2/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.8489 - accuracy: 0.1869 - val_loss: 1.6087 - val_accuracy: 0.2313
# Epoch 3/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.8138 - accuracy: 0.1944 - val_loss: 1.6140 - val_accuracy: 0.2313
# Epoch 4/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.7640 - accuracy: 0.2112 - val_loss: 1.6100 - val_accuracy: 0.1791
# Epoch 5/100
# 5/5 [==============================] - 0s 28ms/step - loss: 1.7741 - accuracy: 0.1832 - val_loss: 1.6097 - val_accuracy: 0.2090
# Epoch 6/100
# 5/5 [==============================] - 0s 28ms/step - loss: 1.7651 - accuracy: 0.2075 - val_loss: 1.6078 - val_accuracy: 0.2090
# Epoch 7/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.7744 - accuracy: 0.2243 - val_loss: 1.6021 - val_accuracy: 0.2463
# Epoch 8/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.7282 - accuracy: 0.2131 - val_loss: 1.5517 - val_accuracy: 0.3582
# Epoch 9/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.6659 - accuracy: 0.2093 - val_loss: 1.4891 - val_accuracy: 0.3358
# Epoch 10/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.5772 - accuracy: 0.2972 - val_loss: 1.4391 - val_accuracy: 0.4030
# Epoch 11/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.4772 - accuracy: 0.3495 - val_loss: 1.3935 - val_accuracy: 0.3582
# Epoch 12/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.4478 - accuracy: 0.3757 - val_loss: 1.3798 - val_accuracy: 0.3358
# Epoch 13/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3849 - accuracy: 0.4112 - val_loss: 1.2936 - val_accuracy: 0.5149
# Epoch 14/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.3193 - accuracy: 0.4561 - val_loss: 1.2623 - val_accuracy: 0.4627
# Epoch 15/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.2383 - accuracy: 0.4673 - val_loss: 1.2283 - val_accuracy: 0.5224
# Epoch 16/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2210 - accuracy: 0.4991 - val_loss: 1.1560 - val_accuracy: 0.5597
# Epoch 17/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1052 - accuracy: 0.5477 - val_loss: 1.1361 - val_accuracy: 0.6269
# Epoch 18/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.1268 - accuracy: 0.5570 - val_loss: 1.0740 - val_accuracy: 0.5970
# Epoch 19/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.0879 - accuracy: 0.5944 - val_loss: 1.1106 - val_accuracy: 0.5821
# Epoch 20/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.0418 - accuracy: 0.6019 - val_loss: 1.1293 - val_accuracy: 0.5896
# Epoch 21/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.0240 - accuracy: 0.5963 - val_loss: 1.0779 - val_accuracy: 0.6194
# Epoch 22/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.9675 - accuracy: 0.6187 - val_loss: 1.0589 - val_accuracy: 0.6269
# Epoch 23/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.9081 - accuracy: 0.6505 - val_loss: 1.0300 - val_accuracy: 0.6343
# Epoch 24/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.9614 - accuracy: 0.6019 - val_loss: 0.9897 - val_accuracy: 0.6045
# Epoch 25/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.8521 - accuracy: 0.6897 - val_loss: 0.9896 - val_accuracy: 0.6119
# Epoch 26/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.9157 - accuracy: 0.6374 - val_loss: 0.9581 - val_accuracy: 0.6418
# Epoch 27/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.8487 - accuracy: 0.6935 - val_loss: 0.9086 - val_accuracy: 0.6642
# Epoch 28/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.8178 - accuracy: 0.6991 - val_loss: 0.9346 - val_accuracy: 0.6791
# Epoch 29/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.8129 - accuracy: 0.6991 - val_loss: 0.8773 - val_accuracy: 0.6493
# Epoch 30/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.8098 - accuracy: 0.6972 - val_loss: 0.8671 - val_accuracy: 0.6791
# Epoch 31/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7721 - accuracy: 0.7364 - val_loss: 0.8278 - val_accuracy: 0.7015
# Epoch 32/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7367 - accuracy: 0.7439 - val_loss: 0.8314 - val_accuracy: 0.6940
# Epoch 33/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.7121 - accuracy: 0.7402 - val_loss: 0.7804 - val_accuracy: 0.7612
# Epoch 34/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7001 - accuracy: 0.7495 - val_loss: 0.7815 - val_accuracy: 0.7537
# Epoch 35/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.6841 - accuracy: 0.7589 - val_loss: 0.7774 - val_accuracy: 0.7164
# Epoch 36/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6488 - accuracy: 0.7514 - val_loss: 0.7574 - val_accuracy: 0.7164
# Epoch 37/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6578 - accuracy: 0.7570 - val_loss: 0.7935 - val_accuracy: 0.7239
# Epoch 38/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.6550 - accuracy: 0.7664 - val_loss: 0.7208 - val_accuracy: 0.7761
# Epoch 39/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6246 - accuracy: 0.7776 - val_loss: 0.7005 - val_accuracy: 0.7761
# Epoch 40/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5744 - accuracy: 0.7832 - val_loss: 0.6854 - val_accuracy: 0.7612
# Epoch 41/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6096 - accuracy: 0.8037 - val_loss: 0.7001 - val_accuracy: 0.7836
# Epoch 42/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6166 - accuracy: 0.7607 - val_loss: 0.6582 - val_accuracy: 0.7537
# Epoch 43/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5893 - accuracy: 0.7869 - val_loss: 0.6581 - val_accuracy: 0.7910
# Epoch 44/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5674 - accuracy: 0.7981 - val_loss: 0.6553 - val_accuracy: 0.7761
# Epoch 45/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5859 - accuracy: 0.8000 - val_loss: 0.6532 - val_accuracy: 0.7761
# Epoch 46/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5567 - accuracy: 0.7963 - val_loss: 0.6625 - val_accuracy: 0.8134
# Epoch 47/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5410 - accuracy: 0.8168 - val_loss: 0.6598 - val_accuracy: 0.8060
# Epoch 48/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5276 - accuracy: 0.8318 - val_loss: 0.6079 - val_accuracy: 0.8134
# Epoch 49/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5176 - accuracy: 0.8374 - val_loss: 0.6065 - val_accuracy: 0.7985
# Epoch 50/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5389 - accuracy: 0.8075 - val_loss: 0.6429 - val_accuracy: 0.8209
# Epoch 51/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5401 - accuracy: 0.8224 - val_loss: 0.6418 - val_accuracy: 0.7836
# Epoch 52/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5321 - accuracy: 0.8336 - val_loss: 0.5932 - val_accuracy: 0.8209
# Epoch 53/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5336 - accuracy: 0.8112 - val_loss: 0.5627 - val_accuracy: 0.8358
# Epoch 54/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4699 - accuracy: 0.8393 - val_loss: 0.5912 - val_accuracy: 0.7985
# Epoch 55/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5787 - accuracy: 0.7869 - val_loss: 0.6124 - val_accuracy: 0.8134
# Epoch 56/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5551 - accuracy: 0.8056 - val_loss: 0.5585 - val_accuracy: 0.8433
# Epoch 57/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5405 - accuracy: 0.8075 - val_loss: 0.6055 - val_accuracy: 0.8060
# Epoch 58/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4697 - accuracy: 0.8449 - val_loss: 0.5485 - val_accuracy: 0.8358
# Epoch 59/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4921 - accuracy: 0.8374 - val_loss: 0.6696 - val_accuracy: 0.7687
# Epoch 60/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5031 - accuracy: 0.8262 - val_loss: 0.5608 - val_accuracy: 0.8358
# Epoch 61/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4484 - accuracy: 0.8486 - val_loss: 0.6289 - val_accuracy: 0.7985
# Epoch 62/100
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4195 - accuracy: 0.8496

# %%
model.evaluate(X_test, Y_test, verbose=0)
# Out:
# [0.22290681302547455, 0.9179104566574097]
